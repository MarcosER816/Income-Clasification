# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn

# %%
from pandas import read_csv

# %%
path=("/content/us-adult-income-update/census.csv")
data=read_csv(path)
data.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male           0.0           0.0
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 2    Protective-serv      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                  ?    Own-child  White  Female           0.0           0.0
#
#    hours-per-week native-country income
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       25           Private  226802          11th              7
# 1       38           Private   89814       HS-grad              9
# 2       28         Local-gov  336951    Assoc-acdm             12
# 3       44           Private  160323  Some-college             10
# 4       18                 ?  103497  Some-college             10
# ...    ...               ...     ...           ...            ...
# 19413   43           Private  300528  Some-college             10
# 19414   45           Private   67716       HS-grad              9
# 19415   48       Federal-gov  326048     Bachelors             13
# 19416   60           Private  191188       HS-grad              9
# 19417   45  Self-emp-not-inc   32172  Some-college             10
#
#            marital-status         occupation relationship   race     sex  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
print(f'Number of Rows: {df.shape[0]}')
print(f'Number of Columns: {df.shape[1]}')
# Out:
# Number of Rows: 19418
# Number of Columns: 15

# %%
for i, col in enumerate(df.columns):
  print(df.columns[i], '::\n', df[str(col)].unique(), '\n\n')
# Out:
# age ::
#  [25 38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87]
#
#
# workclass ::
#  ['Private' 'Local-gov' '?' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
#
# fnlwgt ::
#  [226802  89814 336951 ... 237865 300528 191188]
#
#
# education ::
#  ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
#
#
# education-num ::
#  [ 7  9 12 10  6 15  4 13 14 16  3 11  5  8  2  1]
#
#
# marital-status ::
#  ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
#
#
# occupation ::
#  ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' '?'
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  19418.000000  1.941800e+04   19418.000000  19417.000000  19417.000000
# mean      38.774848  1.894894e+05      10.077351   1073.547098     89.447958
# std       13.804124  1.056916e+05       2.565492   7505.221020    406.068843
# min       17.000000  1.349200e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.169790e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.778355e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.385670e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   3770.000000
#
#        hours-per-week
# count    19417.000000
# mean        40.416233
# std         12.420713
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19418 entries, 0 to 19417
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             19418 non-null  int64
#  1   workclass       19418 non-null  object
#  2   fnlwgt          19418 non-null  int64
#  3   education       19418 non-null  object
#  4   education-num   19418 non-null  int64
#  5   marital-status  19418 non-null  object
#  6   occupation      19418 non-null  object
#  7   relationship    19417 non-null  object
#  8   race            19417 non-null  object
#  9   sex             19417 non-null  object
#  10  capital-gain    19417 non-null  float64
#  11  capital-loss    19417 non-null  float64
#  12  hours-per-week  19417 non-null  float64
#  13  native-country  19417 non-null  object
#  14  income          19417 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 2.2+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      1
# race              1
# sex               1
# capital-gain      1
# capital-loss      1
# hours-per-week    1
# native-country    1
# income            1
# dtype: int64

# %%
df.isin(['?']).sum(axis=0)
# Out:
# age                  0
# workclass         1164
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1167
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     335
# income               0
# dtype: int64

# %%
df.replace("?", np.nan, inplace = True)
df.isna().sum()
# Out:
# age                  0
# workclass         1164
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1167
# relationship         1
# race                 1
# sex                  1
# capital-gain         1
# capital-loss         1
# hours-per-week       1
# native-country     336
# income               1
# dtype: int64

# %%
df=df.dropna()
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df
# Out:
#        age    workclass  fnlwgt     education  education-num  \
# 0       25      Private  226802          11th              7
# 1       38      Private   89814       HS-grad              9
# 2       28    Local-gov  336951    Assoc-acdm             12
# 3       44      Private  160323  Some-college             10
# 5       34      Private  198693          10th              6
# ...    ...          ...     ...           ...            ...
# 19411   41      Private  179875          11th              7
# 19413   43      Private  300528  Some-college             10
# 19414   45      Private   67716       HS-grad              9
# 19415   48  Federal-gov  326048     Bachelors             13
# 19416   60      Private  191188       HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
from IPython.display import display

for columna in df.columns:

    tabla = (
        df[columna]
        .value_counts(dropna=False)
        .reset_index()
    )

    tabla.columns = [columna, "Cantidad"]

    print(f"\n\n===== {columna} =====")
    display(tabla)
# Out:
# ===== age =====
#     age  Cantidad
# 0    35       527
# 1    31       518
# 2    33       505
# 3    36       503
# 4    23       494
# ..  ...       ...
# 68   88         3
# 69   85         2
# 70   89         1
# 71   87         1
# 72   84         1
#
# [73 rows x 2 columns]
# ===== workclass =====
#           workclass  Cantidad
# 0           Private     13128
# 1  Self-emp-not-inc      1540
# 2         Local-gov      1238
# 3         State-gov       793
# 4      Self-emp-inc       685
# 5       Federal-gov       548
# 6       Without-pay         8
# ===== fnlwgt =====
#        fnlwgt  Cantidad
# 0      125892        10
# 1      136986         9
# 2      111567         9
# 3      120277         9
# 4      127651         8
# ...       ...       ...
# 13734  200639         1
# 13735  267546         1
# 13736  179875         1
# 13737  300528         1
# 13738   82091         1
#
# [13739 rows x 2 columns]
# ===== education =====
#        education  Cantidad
# ...

# %%
df["income"] = df["income"].map({
    "<=50K": 0,
    ">50K": 1
})
# Out:
# /tmp/ipykernel_2846/4009529802.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["income"] = df["income"].map({

# %%
y = df["income"]
x = df.drop("income", axis=1)
x.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 5   34    Private  198693          10th              6       Never-married
#
#           occupation   relationship   race   sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black  Male           0.0           0.0
# 1    Farming-fishing        Husband  White  Male           0.0           0.0
# 2    Protective-serv        Husband  White  Male           0.0           0.0
# 3  Machine-op-inspct        Husband  Black  Male        7688.0           0.0
# 5      Other-service  Not-in-family  White  Male           0.0           0.0
#
#    hours-per-week native-country
# ...

# %%
# Columnas categóricas
columnas_categoricas = x.select_dtypes(include=['object']).columns

print(columnas_categoricas)
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country'],
#       dtype='object')

# %%
x = pd.get_dummies(
    x,
    columns=columnas_categoricas,
    dtype=int
)

x.head()
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   25  226802              7           0.0           0.0            40.0
# 1   38   89814              9           0.0           0.0            50.0
# 2   28  336951             12           0.0           0.0            40.0
# 3   44  160323             10        7688.0           0.0            40.0
# 5   34  198693              6           0.0           0.0            30.0
#
#    workclass_Federal-gov  workclass_Local-gov  workclass_Private  \
# 0                      0                    0                  1
# 1                      0                    0                  1
# 2                      0                    1                  0
# 3                      0                    0                  1
# 5                      0                    0                  1
#
#    workclass_Self-emp-inc  ...  native-country_Portugal  \
# 0                       0  ...                        0
# ...

# %%
df_corr = x.copy()

df_corr["income"] = y

correlaciones = df_corr.corr()["income"]

correlaciones = correlaciones.abs().sort_values(
    ascending=False
)

print(correlaciones.head(50))
# Out:
# income                                  1.000000
# marital-status_Married-civ-spouse       0.452160
# relationship_Husband                    0.409513
# education-num                           0.326975
# marital-status_Never-married            0.320202
# age                                     0.228412
# hours-per-week                          0.224814
# capital-gain                            0.220856
# relationship_Own-child                  0.217121
# sex_Male                                0.211093
# sex_Female                              0.211093
# occupation_Exec-managerial              0.206027
# relationship_Not-in-family              0.203148
# occupation_Prof-specialty               0.184553
# education_Bachelors                     0.177957
# education_Masters                       0.166766
# occupation_Other-service                0.163646
# relationship_Unmarried                  0.150806
# education_Prof-school                   0.150431
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr_income = (
    df_corr
    .corr()[["income"]]
    .sort_values("income", ascending=False)
)

plt.figure(figsize=(8,25))

sns.heatmap(
    corr_income,
    annot=True,
    cmap="coolwarm",
    center=0
)

plt.title("Correlación de cada variable con income")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x,
    y,
    train_size=0.8,
    random_state=2287
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

modelo = Pipeline([

    (
        "scaler",
        StandardScaler()
    ),

    (
        "model",
        LogisticRegression(
            solver='lbfgs',
            penalty='l2',
            C=1,
            max_iter=5000
        )
    )

])

# %%
modelo.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', LogisticRegression(C=1, max_iter=5000))])

# %%
print(f"Training accuracy: {modelo.score(X_train,y_train):.4f}")

print(f"Test accuracy: {modelo.score(X_test,y_test):.4f}")
# Out:
# Training accuracy: 0.8491
# Test accuracy: 0.8512

# %%
y_pred_train = modelo.predict(X_train)

y_pred_test = modelo.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

acc_train = accuracy_score(
    y_train,
    y_pred_train
)

acc_test = accuracy_score(
    y_test,
    y_pred_test
)

print("Accuracy entrenamiento:", acc_train)

print("Accuracy prueba:", acc_test)
# Out:
# Accuracy entrenamiento: 0.8491499442586399
# Accuracy prueba: 0.8511705685618729

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

precision = precision_score(
    y_test,
    y_pred_test
)

recall = recall_score(
    y_test,
    y_pred_test
)

f1 = f1_score(
    y_test,
    y_pred_test
)

print("Precision:", precision)
print("Recall:", recall)
print("F1:", f1)
# Out:
# Precision: 0.7235142118863049
# Recall: 0.6363636363636364
# F1: 0.6771463119709794

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_test,
        y_pred_test
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      2708
#            1       0.72      0.64      0.68       880
#
#     accuracy                           0.85      3588
#    macro avg       0.80      0.78      0.79      3588
# weighted avg       0.85      0.85      0.85      3588

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(
    y_test,
    y_pred_test
)

print(cm)
# Out:
# [[2494  214]
#  [ 320  560]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicción")

plt.ylabel("Valor Real")

plt.title("Matriz de Confusión")

plt.show()

# %%
from sklearn.metrics import roc_auc_score

y_pred_probs = modelo.predict_proba(X_test)

roc_auc = roc_auc_score(
    y_test,
    y_pred_probs[:,1]
)

print("ROC-AUC:", roc_auc)
# Out:
# ROC-AUC: 0.9062432858869344

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(
    y_test,
    y_pred_probs[:,1]
)

plt.figure(figsize=(7,5))

plt.plot(
    fpr,
    tpr,
    linewidth=2
)

plt.plot(
    [0,1],
    [0,1],
    '--'
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curva ROC")

plt.show()

# %%
coeficientes = pd.DataFrame({

    "Variable": X_train.columns,

    "Coeficiente":
    modelo.named_steps["model"].coef_[0]

})

coeficientes = coeficientes.sort_values(
    by="Coeficiente",
    ascending=False
)

# %%
coeficientes.head(15)
# Out:
#                              Variable  Coeficiente
# 3                        capital-gain     2.422841
# 31  marital-status_Married-civ-spouse     0.879012
# 5                      hours-per-week     0.343199
# 0                                 age     0.342016
# 2                       education-num     0.337526
# 4                        capital-loss     0.262683
# 39         occupation_Exec-managerial     0.249729
# 51         relationship_Not-in-family     0.192488
# 45          occupation_Prof-specialty     0.171667
# 22                education_Bachelors     0.149543
# 57            race_Asian-Pac-Islander     0.133929
# 6               workclass_Federal-gov     0.125334
# 27              education_Prof-school     0.122798
# 25                  education_Masters     0.117787
# 55                  relationship_Wife     0.114196

# %%
coeficientes.tail(15)
# Out:
#                           Variable  Coeficiente
# 87           native-country_Mexico    -0.121993
# 41    occupation_Handlers-cleaners    -0.129272
# 13                  education_10th    -0.139561
# 35          marital-status_Widowed    -0.144863
# 34        marital-status_Separated    -0.146305
# 10      workclass_Self-emp-not-inc    -0.146507
# 14                  education_11th    -0.147326
# 99  native-country_Trinadad&Tobago    -0.148478
# 75        native-country_Guatemala    -0.152153
# 95         native-country_Scotland    -0.159060
# 53          relationship_Own-child    -0.159971
# 40      occupation_Farming-fishing    -0.167057
# 43        occupation_Other-service    -0.278602
# 29         marital-status_Divorced    -0.331763
# 33    marital-status_Never-married    -0.570733

# %%
normas = np.abs(
    modelo.named_steps["model"].coef_[0]
)

plt.figure(figsize=(8,5))

sns.histplot(normas)

plt.title(
    "Magnitud de coeficientes"
)

plt.show()

# %% [markdown]
# # **Random Forest**

# %%
# !pip install imbalanced-learn

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score
)

parametros_rf = {

    'n_estimators':[100,200,300],

    'max_depth':[10,20,None],

    'min_samples_split':[2,5,10],

    'min_samples_leaf':[1,2,4]

}

rf_base = RandomForestClassifier(

    random_state=2287,

    n_jobs=-1

)

grid_rf = GridSearchCV(

    estimator=rf_base,

    param_grid=parametros_rf,

    cv=5,

    scoring='f1',

    n_jobs=-1,

    verbose=2

)

grid_rf.fit(
    X_train,
    y_train
)

print("Mejores parámetros RF:")
print(grid_rf.best_params_)

rf = grid_rf.best_estimator_

y_pred_rf = rf.predict(
    X_test
)

print(
    classification_report(
        y_test,
        y_pred_rf
    )
)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Mejores parámetros RF:
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      2708
#            1       0.77      0.64      0.70       880
#
#     accuracy                           0.86      3588
#    macro avg       0.83      0.79      0.80      3588
# weighted avg       0.86      0.86      0.86      3588

# %%
pd.DataFrame(
    grid_rf.cv_results_
)[
    [
        'mean_test_score',
        'params'
    ]
].sort_values(
    'mean_test_score',
    ascending=False
).head(10)
# Out:
#     mean_test_score                                             params
# 68         0.676800  {'max_depth': None, 'min_samples_leaf': 2, 'mi...
# 64         0.675250  {'max_depth': None, 'min_samples_leaf': 2, 'mi...
# 42         0.675219  {'max_depth': 20, 'min_samples_leaf': 2, 'min_...
# 65         0.674969  {'max_depth': None, 'min_samples_leaf': 2, 'mi...
# 69         0.674867  {'max_depth': None, 'min_samples_leaf': 2, 'mi...
# 40         0.674768  {'max_depth': 20, 'min_samples_leaf': 2, 'min_...
# 34         0.674672  {'max_depth': 20, 'min_samples_leaf': 1, 'min_...
# 36         0.674624  {'max_depth': 20, 'min_samples_leaf': 2, 'min_...
# 41         0.674251  {'max_depth': 20, 'min_samples_leaf': 2, 'min_...
# 80         0.674191  {'max_depth': None, 'min_samples_leaf': 4, 'mi...

# %%
from sklearn.metrics import accuracy_score

print(
    "Accuracy RF:",
    accuracy_score(
        y_test,
        y_pred_rf
    )
)
# Out:
# Accuracy RF: 0.8631549609810479

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm_rf = confusion_matrix(
    y_test,
    y_pred_rf
)

plt.figure(figsize=(6,6))

sns.heatmap(
    cm_rf,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title(
    "Random Forest"
)

plt.xlabel("Predicción")
plt.ylabel("Valor Real")

plt.show()

# %%
importancias = pd.DataFrame({

    "Variable": X_train.columns,

    "Importancia": rf.feature_importances_

})

importancias = importancias.sort_values(

    by="Importancia",

    ascending=False

)

importancias.head(20)
# Out:
#                              Variable  Importancia
# 3                        capital-gain     0.129755
# 31  marital-status_Married-civ-spouse     0.102446
# 0                                 age     0.095638
# 2                       education-num     0.091064
# 50               relationship_Husband     0.073963
# 1                              fnlwgt     0.063241
# 5                      hours-per-week     0.061016
# 33       marital-status_Never-married     0.042578
# 4                        capital-loss     0.033099
# 39         occupation_Exec-managerial     0.026165
# 45          occupation_Prof-specialty     0.020911
# 51         relationship_Not-in-family     0.020118
# 22                education_Bachelors     0.016110
# 61                         sex_Female     0.013641
# 62                           sex_Male     0.013467
# 55                  relationship_Wife     0.012773
# 29            marital-status_Divorced     0.011441
# ...

# %%
top = importancias.head(15)

plt.figure(figsize=(10,6))

sns.barplot(

    data=top,

    x="Importancia",

    y="Variable"

)

plt.title(
    "Top 15 Variables Más Importantes"
)

plt.show()

# %% [markdown]
# # **Aumentando clase minoritaria**

# %%
print(y_train.value_counts())
# Out:
# income
# 0    10796
# 1     3556
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(
    sampling_strategy='auto',
    random_state=2287
)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train,
    y_train
)

print("Distribución original:")
print(y_train.value_counts())

print("\nDistribución después de SMOTE:")
print(y_train_smote.value_counts())
# Out:
# Distribución original:
# income
# 0    10796
# 1     3556
# Name: count, dtype: int64
#
# Distribución después de SMOTE:
# income
# 1    10796
# 0    10796
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_smote_scaled = scaler.fit_transform(
    X_train_smote
)

X_test_scaled = scaler.transform(
    X_test
)

# %%
from sklearn.model_selection import (
    train_test_split,
    RandomizedSearchCV
)

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

X_svm_small, _, y_svm_small, _ = train_test_split(
    X_train,
    y_train,
    train_size=0.10,
    stratify=y_train,
    random_state=2287
)

scaler = StandardScaler()

X_svm_small = scaler.fit_transform(
    X_svm_small
)

X_test_scaled = scaler.transform(
    X_test
)

parametros_svm = {

    'C':[0.1,1,5,10],

    'gamma':['scale',0.01],

    'kernel':['rbf']

}

random_svm = RandomizedSearchCV(

    estimator=SVC(
        probability=False,
        random_state=2287
    ),

    param_distributions=parametros_svm,

    n_iter=4,

    cv=3,

    scoring='f1',

    n_jobs=-1,

    verbose=2,

    random_state=2287

)

random_svm.fit(
    X_svm_small,
    y_svm_small
)

print("Mejores parámetros SVM:")
print(random_svm.best_params_)

svm_model = random_svm.best_estimator_
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Mejores parámetros SVM:
# {'kernel': 'rbf', 'gamma': 0.01, 'C': 10}

# %%
pd.DataFrame(
    random_svm.cv_results_
)[
    [
        'mean_test_score',
        'params'
    ]
].sort_values(
    'mean_test_score',
    ascending=False
).head(10)
# Out:
#    mean_test_score                                       params
# 0         0.594139    {'kernel': 'rbf', 'gamma': 0.01, 'C': 10}
# 3         0.571133  {'kernel': 'rbf', 'gamma': 'scale', 'C': 1}
# 1         0.570181     {'kernel': 'rbf', 'gamma': 0.01, 'C': 1}
# 2         0.000000   {'kernel': 'rbf', 'gamma': 0.01, 'C': 0.1}

# %%
print(y_train_smote.value_counts())
# Out:
# income
# 1    10796
# 0    10796
# Name: count, dtype: int64

# %% [markdown]
# # **SVM**

# %%
from sklearn.svm import SVC

svm_model = SVC(

    kernel='rbf',

    C=2,

    gamma='scale',

    probability=True,

    random_state=2287
)

svm_model.fit(

    X_train_smote_scaled,

    y_train_smote
)
# Out:
# SVC(C=2, probability=True, random_state=2287)

# %% [markdown]
# # **Resultados SVM + Smote**

# %%
y_pred_svm = svm_model.predict(
    X_test_scaled
)

print(

    classification_report(
        y_test,
        y_pred_svm
    )

)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78      2708
#            1       0.46      0.87      0.60       880
#
#     accuracy                           0.72      3588
#    macro avg       0.70      0.77      0.69      3588
# weighted avg       0.82      0.72      0.74      3588

# %%
y_prob_svm = svm_model.predict_proba(
    X_test_scaled
)

roc_svm = roc_auc_score(

    y_test,

    y_prob_svm[:,1]
)

print(
    "ROC AUC SVM:",
    roc_svm
)
# Out:
# ROC AUC SVM: 0.8654563079092251

# %%
cm_svm = confusion_matrix(

    y_test,

    y_pred_svm

)

plt.figure(figsize=(6,6))

sns.heatmap(

    cm_svm,

    annot=True,

    fmt='d',

    cmap='Greens'

)

plt.title(
    "SVM + SMOTE"
)

plt.xlabel("Predicción")

plt.ylabel("Valor Real")

plt.show()

# %%
from sklearn.metrics import (

    precision_score,

    recall_score,

    f1_score,

    accuracy_score
)

comparacion = pd.DataFrame({

    "Modelo":[

        "Logistic Regression",

        "Random Forest",

        "SVM + SMOTE"

    ],

    "Accuracy":[

        accuracy_score(
            y_test,
            y_pred_test
        ),

        accuracy_score(
            y_test,
            y_pred_rf
        ),

        accuracy_score(
            y_test,
            y_pred_svm
        )
    ],

    "Precision":[

        precision_score(
            y_test,
            y_pred_test
        ),

        precision_score(
            y_test,
            y_pred_rf
        ),

        precision_score(
            y_test,
            y_pred_svm
        )
    ],

    "Recall":[

        recall_score(
            y_test,
            y_pred_test
        ),

        recall_score(
            y_test,
            y_pred_rf
        ),

        recall_score(
            y_test,
            y_pred_svm
        )
    ],

    "F1":[

        f1_score(
            y_test,
            y_pred_test
        ),

        f1_score(
            y_test,
            y_pred_rf
        ),

        f1_score(
            y_test,
            y_pred_svm
        )
    ]

})

comparacion
# Out:
#                 Modelo  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.851171   0.723514  0.636364  0.677146
# 1        Random Forest  0.863155   0.765348  0.637500  0.695598
# 2          SVM + SMOTE  0.720178   0.462651  0.872727  0.604724

# %% [markdown]
# # **Red neuronal (NN)**

# %%
from sklearn.preprocessing import StandardScaler

scaler_nn = StandardScaler()

X_train_scaled = scaler_nn.fit_transform(
    X_train
)

X_test_scaled = scaler_nn.transform(
    X_test
)

# %%
from sklearn.neural_network import MLPClassifier

nn = MLPClassifier(

    hidden_layer_sizes=(128,64,32),

    activation='relu',

    solver='adam',

    alpha=0.0001,

    batch_size=128,

    learning_rate='adaptive',

    max_iter=500,

    random_state=2287

)

# %%
nn.fit(
    X_train_scaled,
    y_train
)
# Out:
# MLPClassifier(batch_size=128, hidden_layer_sizes=(128, 64, 32),
#               learning_rate='adaptive', max_iter=500, random_state=2287)

# %% [markdown]
# # **resultados NN**

# %%
y_pred_nn = nn.predict(
    X_test_scaled
)

print(
    classification_report(
        y_test,
        y_pred_nn
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      2708
#            1       0.65      0.55      0.60       880
#
#     accuracy                           0.82      3588
#    macro avg       0.76      0.73      0.74      3588
# weighted avg       0.81      0.82      0.81      3588

# %%
from sklearn.metrics import accuracy_score

print(
    "Accuracy NN:",
    accuracy_score(
        y_test,
        y_pred_nn
    )
)
# Out:
# Accuracy NN: 0.8180044593088072

# %%
from sklearn.metrics import roc_auc_score

y_prob_nn = nn.predict_proba(
    X_test_scaled
)

roc_nn = roc_auc_score(
    y_test,
    y_prob_nn[:,1]
)

print(
    "ROC AUC NN:",
    roc_nn
)
# Out:
# ROC AUC NN: 0.862195766751712

# %% [markdown]
# # **Matriz de confucion red neuronal**

# %%
from sklearn.metrics import confusion_matrix

cm_nn = confusion_matrix(
    y_test,
    y_pred_nn
)

plt.figure(figsize=(6,6))

sns.heatmap(
    cm_nn,
    annot=True,
    fmt='d',
    cmap='Purples'
)

plt.title(
    "Red Neuronal"
)

plt.xlabel("Predicción")
plt.ylabel("Valor Real")

plt.show()

# %% [markdown]
# # **Sacando matrices de confucion**

# %%
cm_lr = confusion_matrix(
    y_test,
    y_pred_test
)

tn_lr, fp_lr, fn_lr, tp_lr = cm_lr.ravel()

# %%
cm_rf = confusion_matrix(
    y_test,
    y_pred_rf
)

tn_rf, fp_rf, fn_rf, tp_rf = cm_rf.ravel()

# %%
cm_svm = confusion_matrix(
    y_test,
    y_pred_svm
)

tn_svm, fp_svm, fn_svm, tp_svm = cm_svm.ravel()

# %%
cm_nn = confusion_matrix(
    y_test,
    y_pred_nn
)

tn_nn, fp_nn, fn_nn, tp_nn = cm_nn.ravel()

# %% [markdown]
# # **Valores fp y fn**

# %%
comparacion_errores = pd.DataFrame({

    "Modelo":[

        "Logistic Regression",

        "Random Forest",

        "SVM + SMOTE",

        "Red Neuronal"

    ],

    "Falsos Positivos":[

        fp_lr,

        fp_rf,

        fp_svm,

        fp_nn

    ],

    "Falsos Negativos":[

        fn_lr,

        fn_rf,

        fn_svm,

        fn_nn

    ]

})

comparacion_errores
# Out:
#                 Modelo  Falsos Positivos  Falsos Negativos
# 0  Logistic Regression               214               320
# 1        Random Forest               172               319
# 2          SVM + SMOTE               892               112
# 3         Red Neuronal               259               394

# %%
comparacion_errores.set_index(
    "Modelo"
).plot(

    kind='bar',

    figsize=(10,6)

)

plt.title(
    "Comparación de Falsos Positivos y Falsos Negativos"
)

plt.ylabel(
    "Cantidad"
)

plt.grid()

plt.show()

# %%
from sklearn.metrics import (

    precision_score,

    recall_score,

    f1_score,

    accuracy_score

)

comparacion = pd.DataFrame({

    "Modelo":[

        "Logistic Regression",

        "Random Forest",

        "SVM + SMOTE",

        "Red Neuronal"

    ],

    "Accuracy":[

        accuracy_score(
            y_test,
            y_pred_test
        ),

        accuracy_score(
            y_test,
            y_pred_rf
        ),

        accuracy_score(
            y_test,
            y_pred_svm
        ),

        accuracy_score(
            y_test,
            y_pred_nn
        )
    ],

    "Precision":[

        precision_score(
            y_test,
            y_pred_test
        ),

        precision_score(
            y_test,
            y_pred_rf
        ),

        precision_score(
            y_test,
            y_pred_svm
        ),

        precision_score(
            y_test,
            y_pred_nn
        )
    ],

    "Recall":[

        recall_score(
            y_test,
            y_pred_test
        ),

        recall_score(
            y_test,
            y_pred_rf
        ),

        recall_score(
            y_test,
            y_pred_svm
        ),

        recall_score(
            y_test,
            y_pred_nn
        )
    ],

    "F1":[

        f1_score(
            y_test,
            y_pred_test
        ),

        f1_score(
            y_test,
            y_pred_rf
        ),

        f1_score(
            y_test,
            y_pred_svm
        ),

        f1_score(
            y_test,
            y_pred_nn
        )
    ]

})

comparacion
# Out:
#                 Modelo  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.851171   0.723514  0.636364  0.677146
# 1        Random Forest  0.863155   0.765348  0.637500  0.695598
# 2          SVM + SMOTE  0.720178   0.462651  0.872727  0.604724
# 3         Red Neuronal  0.818004   0.652349  0.552273  0.598154

# %% [markdown]
# # **Comparacion entre los cuatro metodos**

# %%
fig, axes = plt.subplots(
    2,
    2,
    figsize=(12,10)
)

sns.heatmap(
    cm_lr,
    annot=True,
    fmt='d',
    cmap='Blues',
    ax=axes[0,0]
)

axes[0,0].set_title(
    "Logistic Regression"
)

sns.heatmap(
    cm_rf,
    annot=True,
    fmt='d',
    cmap='Greens',
    ax=axes[0,1]
)

axes[0,1].set_title(
    "Random Forest"
)

sns.heatmap(
    cm_svm,
    annot=True,
    fmt='d',
    cmap='Reds',
    ax=axes[1,0]
)

axes[1,0].set_title(
    "SVM + SMOTE"
)

sns.heatmap(
    cm_nn,
    annot=True,
    fmt='d',
    cmap='Purples',
    ax=axes[1,1]
)

axes[1,1].set_title(
    "Red Neuronal"
)

plt.tight_layout()

plt.show()

# %%
resumen_final = pd.DataFrame({

    "Modelo":[
        "Logistic Regression",
        "Random Forest",
        "SVM + SMOTE",
        "Red Neuronal"
    ],

    "FP":[
        fp_lr,
        fp_rf,
        fp_svm,
        fp_nn
    ],

    "FN":[
        fn_lr,
        fn_rf,
        fn_svm,
        fn_nn
    ],

    "Accuracy":[
        accuracy_score(y_test,y_pred_test),
        accuracy_score(y_test,y_pred_rf),
        accuracy_score(y_test,y_pred_svm),
        accuracy_score(y_test,y_pred_nn)
    ],

    "Recall":[
        recall_score(y_test,y_pred_test),
        recall_score(y_test,y_pred_rf),
        recall_score(y_test,y_pred_svm),
        recall_score(y_test,y_pred_nn)
    ]

})

resumen_final.sort_values(
    "Recall",
    ascending=False
)
# Out:
#                 Modelo   FP   FN  Accuracy    Recall
# 2          SVM + SMOTE  892  112  0.720178  0.872727
# 1        Random Forest  172  319  0.863155  0.637500
# 0  Logistic Regression  214  320  0.851171  0.636364
# 3         Red Neuronal  259  394  0.818004  0.552273
